# %% [markdown]
# # Split

# %%
import os
import sys
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

warnings.filterwarnings('ignore')

# %%
sys.path.append(os.path.join('..', 'src'))

# %%
import importlib
import utils
importlib.reload(utils)
from utils import capture_data

# %% [markdown]
# # define functions

# %%
def save_csv(sufix, label=False):
    file = sufix + '.csv'
    if label==False: 
        df = eval(sufix)
    else: 
        df = pd.DataFrame(eval(sufix), columns=['y'])
    df.to_csv(os.path.join(outputs, file))

# %% [markdown]
# # set sampling to True/False
# * if sampling_data == True: faster to run project, but will work on a data sample

# %%
sampling_data = True

# %%
sample_size = 5000

# %% [markdown]
# # Define paths and capture data

# %%
inputs = os.path.join('..', 'data', '02_intermediate')
outputs = os.path.join('..', 'data', '02_intermediate')
reports = os.path.join('..', 'data', '06_reporting')

data = capture_data(inputs, 'data.csv')
data_test = capture_data(inputs, 'data_test.csv')

# %%
print('Dataset dimensions:', data.shape)
data.head()
# Out:
# Dataset dimensions: (32561, 14)
#     age         workclass  education  education_num      marital_status  \
# id
# 0    39         State-gov  Bachelors             13       Never-married
# 1    50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2    38           Private    HS-grad              9            Divorced
# 3    53           Private       11th              7  Married-civ-spouse
# 4    28           Private  Bachelors             13  Married-civ-spouse
#
#            occupation   relationship   race     sex  capital_gain  \
# id
# 0        Adm-clerical  Not-in-family  White    Male          2174
# 1     Exec-managerial        Husband  White    Male             0
# 2   Handlers-cleaners  Not-in-family  White    Male             0
# 3   Handlers-cleaners        Husband  Black    Male             0
# 4      Prof-specialty           Wife  Black  Female             0
#
#     capital_loss  hours_per_week native_country    y
# id
# 0              0              40  United-States  0.0
# 1              0              13  United-States  0.0
# 2              0              40  United-States  0.0
# 3              0              40  United-States  0.0
# 4              0              40           Cuba  0.0

# %%
print('Dataset dimensions:', data_test.shape)
data_test.head()
# Out:
# Dataset dimensions: (16281, 14)
#     age         workclass  education  education_num      marital_status  \
# id
# 0    25         State-gov  Bachelors              7       Never-married
# 1    38  Self-emp-not-inc  Bachelors              9  Married-civ-spouse
# 2    28           Private    HS-grad             12            Divorced
# 3    44           Private       11th             10  Married-civ-spouse
# 4    18           Private  Bachelors             10  Married-civ-spouse
#
#            occupation   relationship   race     sex  capital_gain  \
# id
# 0        Adm-clerical  Not-in-family  White    Male             0
# 1     Exec-managerial        Husband  White    Male             0
# 2   Handlers-cleaners  Not-in-family  White    Male             0
# 3   Handlers-cleaners        Husband  Black    Male          7688
# 4      Prof-specialty           Wife  Black  Female             0
#
#     capital_loss  hours_per_week native_country    y
# id
# 0              0              40  United-States  0.0
# 1              0              50  United-States  0.0
# 2              0              40  United-States  0.0
# 3              0              40  United-States  0.0
# 4              0              30           Cuba  0.0

# %% [markdown]
# # data sampling
# if sampling_data == True: faster to run project, but will work on a data sample

# %%
if sampling_data == True:
    data = data.sample(sample_size, random_state=42)
data.shape
# Out:
# (5000, 14)

# %% [markdown]
# # final description

# %%
data.tail()
# Out:
#        age         workclass  education  education_num      marital_status  \
# id
# 27453   32  Self-emp-not-inc    HS-grad              9  Married-civ-spouse
# 27161   43           Private    HS-grad              9  Married-civ-spouse
# 17926   35           Private    HS-grad              9            Divorced
# 25713   32           Private  Assoc-voc             11  Married-civ-spouse
# 3334    26           Private    HS-grad              9       Never-married
#
#               occupation relationship   race   sex  capital_gain  \
# id
# 27453   Transport-moving      Husband  White  Male             0
# 27161    Exec-managerial      Husband  White  Male             0
# 17926       Craft-repair    Unmarried  White  Male             0
# 25713   Transport-moving      Husband  White  Male             0
# 3334   Handlers-cleaners    Own-child  Black  Male             0
#
#        capital_loss  hours_per_week native_country    y
# id
# 27453             0              48  United-States  0.0
# 27161             0              40  United-States  1.0
# 17926             0              40  United-States  0.0
# 25713             0              99  United-States  1.0
# 3334              0              40  United-States  0.0

# %%
data.describe()
# Out:
#                age  education_num  capital_gain  capital_loss  hours_per_week  \
# count  5000.000000    5000.000000   5000.000000   5000.000000      5000.00000
# mean     38.793600      10.065000   1130.159400     87.180000        40.67960
# std      13.688304       2.555246   7583.026928    406.812837        12.26164
# min      17.000000       1.000000      0.000000      0.000000         1.00000
# 25%      28.000000       9.000000      0.000000      0.000000        40.00000
# 50%      37.000000      10.000000      0.000000      0.000000        40.00000
# 75%      48.000000      12.000000      0.000000      0.000000        45.00000
# max      90.000000      16.000000  99999.000000   4356.000000        99.00000
#
#                  y
# count  5000.000000
# mean      0.245600
# std       0.430485
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# # Split data
# test_size could depend on data size. For instance, for 1 million entries, it would work fine to establish test_size=0.1.
#
# But let's notice that we already have train and test sets! So we just need to separate the response variable!
#
# if we wanted to split by using some handy function, the approach would be :
# ```python
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
# ```

# %%
X_train = data.loc[:, data.columns != 'y']
y_train = data.loc[:, 'y']
print('dimensions of X:', X_train.shape)
print('dimensions of y:', y_train.shape)

X_test = data_test.loc[:, data_test.columns != 'y']
y_test = data_test.loc[:, 'y']
print('\r\ndimensions of X:', X_test.shape)
print('dimensions of y:', y_test.shape)
# Out:
# dimensions of X: (5000, 13)
# dimensions of y: (5000,)
#
# dimensions of X: (16281, 13)
# dimensions of y: (16281,)

# %% [markdown]
# # save train and test sets

# %%
for file_sufix in ['X_train', 'X_test']:
    save_csv(file_sufix)
for file_sufix in ['y_train', 'y_test']:
    save_csv(file_sufix, label=True)
